# %%
import pandas as pd

OHLC = { "timestamp","symbol","open","high","low","close","volume"}

df = pd.DataFrame(OHLC)

print(df)
# Out:
#            0
# 0     volume
# 1     symbol
# 2      close
# 3       high
# 4  timestamp
# 5       open
# 6        low

# %%
df.to_parquet("OHLC.pq")
pd.read_parquet("OHLC.pq")
# Out:
#            0
# 0     volume
# 1     symbol
# 2      close
# 3       high
# 4  timestamp
# 5       open
# 6        low
