# %% [markdown]
# # Regime-Adaptive Intraday Alpha Program
# ### Dual-Architecture Quantitative Research Framework
# ### Structural Hypothesis Testing, Parameter Governance & Institutional Validation
#
# ---
#
# ## 1. Research Objective
#
# This project develops and evaluates two competing intraday alpha architectures operating on 5-minute bars:
#
# - **Model A (Control): Price-Derivative Momentum Framework**
# - **Model B (Experimental): Flow-Structural Microstructure Framework**
#
# The objective is to determine whether:
#
# > Traditional short-horizon price momentum (EMA-based structure aligned with VWAP)
# > OR
# > Flow-derived volume pressure signals combined with auction-theory structural filters
#
# exhibit more durable, regime-robust alpha under identical institutional validation controls.
#
# The emphasis of this research is not performance maximization, but:
#
# - Structural hypothesis validation
# - Parameter stability
# - Regime robustness
# - Cost-adjusted durability
# - Statistical credibility
#
# Model A serves as the **control architecture**.
# Model B serves as the **experimental upgrade**.
#
# ---
#
# # PART I — MODEL A (CONTROL)
# ## Price-Derivative Momentum Framework
#
# ---
#
# ## 2. Structural Hypothesis — Model A
#
# The core hypothesis is:
#
# 1. Persistent positioning relative to VWAP reflects intraday institutional directional bias.
# 2. Short-horizon EMA cross events represent momentum inflection points with decaying predictive value.
# 3. Volatility regimes materially affect signal reliability.
# 4. Structural alignment (VWAP + trend + momentum) reduces false positives.
# 5. Risk anchored to structural invalidation improves payoff convexity.
# 6. Intraday signal strength varies by time-of-day and must be statistically derived.
#
# This defines the control signal family.
#
# ---
#
# ## 3. Structural (Non-Optimized) Definitions — Model A
#
# The following define the modeling space and will **not** be statistically tuned:
#
# - 5-minute bar resolution
# - EMA(9,20) as baseline short-horizon momentum pair
# - HMA(20) as structural trend filter
# - RSI(14) and default MACD parameters
# - Fixed notional position sizing
# - Initial capital baseline
#
# These define the hypothesis space.
#
# ---
#
# ## 4. Correlation-Defined Universe Construction — Model A
#
# ### 4.1 Anchor Asset
#
# NVDA is designated as the anchor asset.
#
# ### 4.2 Universe Selection Methodology
#
# For each candidate equity:
#
# $ρ_i = Corr(r_i, r_NVDA)$
#
# Where:
#
# - $r_i$ = daily log returns of stock i
# - $r_NVDA$ = daily log returns of NVDA
# - Correlation window = 252 trading days
#
# Stocks are ranked by rolling correlation during a predefined universe formation period.
#
# The top N correlated stocks form the trading universe.
#
# The universe is frozen before the primary evaluation period to prevent look-ahead bias.
#
# ---
#
# ## 5. Statistically Governed Parameters (Applies to Model A)
#
# The following variables will be empirically derived using controlled statistical analysis:
#
# ### Volatility Conditioning
# - ATR lookback length
# - ATR percentile threshold for participation
#
# ### Momentum Freshness
# - EMA cross freshness window (maximum bar age)
#
# ### Structural Activation
# - VWAP structural activation delay (bars after two-sided confirmation)
# - VWAP proximity band at cross event
#
# ### Risk Management
# - Initial stop-loss distance (VWAP-anchored)
# - Breakeven trigger distance
# - EMA/HMA structural reversal buffer
#
# ### Structural Trend Filters
# - VWAP slope lookback window (longs)
# - VWAP slope lookback window (shorts)
#
# ### Intraday Participation
# - Statistically derived session windows based on time-of-day signal significance
#
# Each parameter will be selected based on:
#
# - Distributional analysis (MAE/MFE)
# - Conditional forward return studies
# - Stability plateaus across neighborhoods
# - Regime robustness
# - Cross-sectional consistency
#
# No parameter will be selected solely on peak Sharpe.
#
# ---
#
# ## 6. Session Derivation Protocol — Model A
#
# 1. Identify all EMA cross events.
# 2. Compute forward returns at multiple horizons.
# 3. Group events by time-of-day buckets.
# 4. Compute:
#    - Mean forward return
#    - t-statistic
#    - Cross-to-cross move distribution
# 5. Exclude time regimes where:
#    - Forward returns are statistically insignificant, or
#    - Cross-to-cross moves are economically negligible.
#
# Session participation is data-driven.
#
# ---
#
# # PART II — MODEL B (EXPERIMENTAL)
# ## Flow-Structural Microstructure Framework
#
# ---
#
# ## 7. Structural Hypothesis — Model B
#
# Model B tests whether intraday alpha is better explained by:
#
# 1. Volume-weighted directional pressure rather than lagging price derivatives.
# 2. Auction-based structural acceptance (POC) rather than arbitrary smoothing filters.
# 3. Liquidity- and volatility-adaptive universe construction.
# 4. Institutional participation intensity via time-relative volume.
# 5. Explicit friction-aware execution modeling.
#
# Model B challenges whether price momentum is the dominant short-horizon signal family.
#
# ---
#
# ## 8. Dynamic Universe Construction — Model B
#
# ### V1 Limitation
# Correlation anchoring introduces:
# - Idiosyncratic regime bias
# - Sector concentration drift
# - Structural macro dependence
#
# ### V2 Implementation
#
# Daily rebalanced universe using strictly lagged data:
#
# 1. Rank equities by 14-day ATR relative to price:
#    ATR_Ratio_i = ATR_14_i / Price_i
#
# 2. Filter for:
#    - Minimum average dollar liquidity
#    - Above-average pre-market participation
#
# 3. Select Top 50 daily.
#
# This ensures capital deployment where volatility and liquidity actually exist.
#
# ---
#
# ## 9. Signal Generation — Estimated Volume Delta (EVD)
#
# Per-bar pressure proxy:
#
# $EVD_t = V_t × ( 2 × (C_t - L_t) / (H_t - L_t) - 1 )$
#
# Interpretation:
#
# - Close near high → buyer dominance
# - Close near low → seller dominance
# - Volume-weighted aggressor pressure approximation
#
# To eliminate historical drag:
#
# Flow_t = rolling sum of recent EVD
# or slope of EVD window.
#
# Window length will be statistically derived and perturbation-tested.
#
# ---
#
# ## 10. Structural Trend Filter — Volume Profile & POC
#
# Construct intraday volume profile using 1-minute or 5-minute data.
#
# POC = price level with highest accepted traded volume during session.
#
# Long condition requires:
# - Price > VWAP
# - Price > POC
#
# Short condition requires:
# - Price < VWAP
# - Price < POC
#
# POC resolution will be stability-tested across price bin sizes.
#
# ---
#
# ## 11. Institutional Participation Filter — Time-of-Day RVOL
#
# Procedure:
#
# 1. Drop half-days and early closes.
# 2. Group bars by exact time-of-day.
# 3. Compute rolling median of last 20 valid same-time observations.
#
# RVOL_t = V_t / Median(V_{t, last 20 valid same-time observations})
#
# Require:
# RVOL_t ≥ threshold (e.g., 2.0, perturbation-tested ± neighborhood).
#
# This ensures structural activation only during institutional participation regimes.
#
# ---
#
# # PART III — COMMON EXECUTION & VALIDATION
#
# ---
#
# ## 12. Execution Model (Shared)
#
# - Signals computed at close of bar t.
# - Entry executed at open of bar t+1.
# - All exits triggered at close of bar t execute at open of bar t+1.
# - No overnight exposure.
# - One active position per asset.
# - Multiple trades per day permitted.
#
# PnL:
#
# Long:
# (Exit − Entry) × Qty
#
# Short:
# (Entry − Exit) × Qty
#
# Performance evaluated separately:
# - Long-only
# - Short-only
# - Combined
#
# ---
#
# ## 13. Transaction Cost Analysis (Applied to Both Models)
#
# 5 bps round-trip (2.5 bps per side).
#
# Long Entry:
# Actual_Entry = Theoretical_Open × (1 + 0.00025)
#
# Long Exit:
# Actual_Exit = Theoretical_Exit × (1 − 0.00025)
#
# Equivalent mirrored logic for shorts.
#
# Sensitivity analysis includes ±1–2 bps perturbation.
#
# Alpha must survive cost-adjusted evaluation.
#
# ---
#
# ## 14. Time Governance & Validation Framework
#
# Data Range: 2016–2026
#
# ### A. Static Parameter Validation
#
# Calibration: 2016–2019
# Out-of-Sample: 2020–2026
#
# Parameters locked post-calibration.
#
# ---
#
# ### B. Rolling Recalibration Validation
#
# Train 2016–2019 → Test 2020
# Train 2017–2020 → Test 2021
# Train 2018–2021 → Test 2022
# Train 2019–2022 → Test 2023
# Train 2020–2023 → Test 2024
# Train 2021–2024 → Test 2025
#
# 2026 remains untouched as final holdout.
#
# ---
#
# ## 15. Structural Stability & Perturbation Analysis
#
# Each model must pass:
#
# - Parameter neighborhood testing
# - Volatility segmentation
# - Regime segmentation
# - Long vs short decomposition
# - Cross-sectional robustness
# - Trade density stability
# - Drawdown profile similarity
#
# Stability criteria:
#
# - Sharpe within acceptable band
# - Trade count does not collapse
# - Drawdown profile remains structurally consistent
#
# No parameter selected solely on peak Sharpe.
#
# ---
#
# ## 16. Core Research Question
#
# This program explicitly tests:
#
# Does traditional short-horizon price momentum outperform flow-derived microstructure pressure signals under identical institutional validation constraints?
#
# If Model B outperforms Model A across:
#
# - Static OOS
# - Rolling validation
# - Cost-adjusted performance
# - Perturbation stability
# - Regime segmentation
#
# Then flow pressure demonstrates structural superiority.
#
# If Model A remains more robust, price momentum remains the dominant structural signal family.
#
# Either outcome is a valid research result.
#
# ---
#
# ## 17. Research Classification
#
# This project represents:
#
# A dual-architecture intraday alpha research program comparing price-derivative momentum signals against flow-structural microstructure signals under disciplined statistical parameter governance, dynamic universe construction, realistic execution modeling, and bias-aware multi-regime validation protocols.
#
# The objective is not to optimize a backtest.
#
# The objective is to determine which structural signal family exhibits durable, statistically defensible alpha.

# %% [markdown]
# We start by importing all the libraries we will need in this project

# %%
import os
import sys
import warnings
from pathlib import Path
from datetime import datetime, timedelta

warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd
import pyarrow as pa
import pyarrow.parquet as pq
import matplotlib.pyplot as plt
import scipy.stats as stats
import yaml
from dotenv import load_dotenv

from alpaca.data.historical import StockHistoricalDataClient
from alpaca.data.requests import StockBarsRequest
from alpaca.data.timeframe import TimeFrame

NOTEBOOK_ROOT = Path.cwd().parent
if str(NOTEBOOK_ROOT) not in sys.path:
    sys.path.insert(0, str(NOTEBOOK_ROOT))

from src.config.settings import (
    PROJECT_ROOT,
    settings,
    cfg,
    client,
    DATA_DIR,
    START_YEAR,
    END_YEAR,
    RAW_PATH,
    DERIVED_PATH,
    FEATURES_PATH,
    UNIVERSE_PATH,
    REPORTS_PATH,
    DATA_START,
    DATA_END,
    FEED,
    ADJUSTMENT,
    TIMEZONE,
)
from src.config.ticker_universe import TICKERS
from src.data_ingestion.fetch_bars import fetch_minute_bars
from src.data_ingestion.parquet_storage import save_to_parquet, load_parquet, parquet_exists
from src.data_ingestion.backfill_pipeline import run_backfill
from src.tests.system_check import run_system_check
from src.data_ingestion.run_ingestion import run_full_backfill

print("Libraries loaded successfully ✅")
print("Tickers:", TICKERS)
print("Raw path:", RAW_PATH)
print("Date range:", DATA_START, "to", DATA_END)
# Out:
# Libraries loaded successfully ✅
# Tickers: ['NVDA', 'AAPL', 'GOOG', 'MSFT', 'AMZN', 'TSM', 'META', 'AVGO', 'TSLA', '005930.KS', 'TECHY', 'ASML', 'ORCL', '000660.KS', 'NFLX', 'MU', 'PLTR', 'AMD', 'BABA', 'CSCO', 'AMAT', 'LRCX', 'IBM', 'SAP', 'KLAC', 'TXN', 'SHOP', 'APP', 'ANET', 'SU.PA', 'UBER', 'ADI', 'BKNG', 'QCOM', 'PDD', 'PANW', 'INTU', 'NOW', 'SONY', 'ARM', '8035.T', 'ADBE', '6857.T', 'SPOT', 'XIACF', 'CRWD', '2308.TW', 'DELL', '2317.TW', '6861.T', 'EQIX', 'ADP', 'MELI', '2454.TW', 'SNPS', 'CDNS', 'ABNB', 'STX', 'MRVL', 'DASH', 'SDNK', '0981.HK', 'NTES', '688256.SS', 'HOOD', 'NET', '7974.T', 'FTNT', 'SNOW', 'TEL', '36990.HK', 'IFX.DE', 'ADSK', 'SE', 'COIN', 'NXPI', '6146.T', 'MPWR', 'UNH', 'HCA', 'MCK', 'CVS', 'CI', 'COR', 'ELV', 'SHL.DE', 'CAH', 'MDLN', 'FRE.DE', 'CNC', 'THC', 'Q0F.SI', '6618.HK', 'RDOR3.SA', 'OHI', '300015.SZ', 'FPH.NZ', 'FMS', 'ENSG', 'SOLV', 'GH', 'LLY', 'JNJ', 'ABBV', 'ROG.SW', 'NVS', 'AZN', 'MRK', 'AMGN', 'GILD', 'NVO', 'PFE', 'BMY', 'VRTX', 'GSK', 'SNY', 'REGN', 'TEK', 'ZTS', 'UCB.VI', '600276.SS', 'CSL.AX', 'GALD.SW', 'SUNPHARMA.NS', 'LONN.SW', 'ARGX', '2359.HK', 'JPM', 'V', 'MA', '1398.HK', 'BAC', '601939.SS', '601288.SS', 'HSBC', 'MS', 'WFC', '601988.SS', 'GS', 'RY', 'AXP', 'CBA.AX', 'MUFG', 'C', 'SCHW', 'SAN', 'TD', '3968.HK', 'HDB', 'SPGI', 'SMFG', 'D05.SI', 'UBS', 'BBVA', 'COF', 'SBIN.NS', 'CME', 'IBKR', 'BNP.PA', 'UCG.MI', '1120.SR', 'ISP.MI', 'IBN', 'NAB.AX', 'BMO', 'MFG', 'WBC.AX', 'ICE', 'CM', 'ITUB', 'BPAC3.SA', 'BNS', '601658.SS', '601328.SS', 'SBER.ME', 'MCO', 'WMT', 'COST', 'HD', 'ITX.MC', 'TJX', 'LOW', '9983.T', 'ROST', 'AZO', 'WES.AX', 'ATD.TO', 'WMMVF', 'TGT', 'L.TO', 'KR', 'AD.AS', 'JD', 'TSCO.L', 'DOL.TO', '8267.T', 'CPNG', 'DG', 'HM-B.ST', 'WOW.AX', 'GE', 'CAT', 'CYATY', 'RTX', 'GEV', 'SMAWF', 'SIEGY', 'BA', 'SBGSF', 'SBGSY', 'EADSY', 'EADSF', 'DE', 'HON', 'ABLZF', 'LMT', 'SAFRY', 'ABBNY', 'SAFRF', 'UNP', 'SMEGF', 'SMERY', 'RYCEY', 'RYCEF', 'HTHIF', 'ETN', 'HTHIY', 'PH', 'MSBHF', 'MTSUY', 'NOC', 'MITSF', 'MITSY', 'DLEGF', 'HW', 'MHVYF', 'MHVIY', 'WM', 'GD', 'ATLPF', 'ITOCF', 'ATLFF', 'TT', 'ATLKY', 'VRT', 'BAESF', 'ITOCY']
# Raw path: /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw
# Date range: 2016-01-01 to 2026-01-30

# %% [markdown]
# We use the Cell below to test the connection to all py files we have and if the configurations are loaded peoperly.
# ### this is run to check that everything is connected

# %%
#testing the connection 
df = run_system_check()
df.head()
# Out:
# ---- SETTINGS SUMMARY ----
# Project name: regime_adaptive_alpha
# Project root: /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha
# Raw path: /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw
# Derived path: /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/derived
# Features path: /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/features
# Universe path: /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/universe
# Reports path: /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/reports
# Configured data window: 2016-01-01 to 2026-01-30
# Adjustment: split
# Feed: sip
# Timezone: America/New_York
# Base timeframe: 1Min
# Derived timeframe: 5Min
# Loaded tickers: 247
# Testing symbol: NVDA
#
# ---- DATA CHECK ----
# Pulled 1441 rows.
# Columns: ['symbol', 'timestamp', 'open', 'high', 'low', 'close', 'volume', 'trade_count', 'vwap']
#   symbol                 timestamp   open   high    low  close   volume  \
# 0   NVDA 2024-01-03 00:02:00+00:00  47.99  47.99  47.98  47.98  11580.0
# 1   NVDA 2024-01-03 00:03:00+00:00  47.98  47.98  47.98  47.98   4810.0
# 2   NVDA 2024-01-03 00:04:00+00:00  47.98  47.98  47.97  47.98  15260.0
# 3   NVDA 2024-01-03 00:05:00+00:00  47.98  47.98  47.96  47.96   4730.0
# 4   NVDA 2024-01-03 00:06:00+00:00  47.97  47.97  47.95  47.95  15410.0
#
#    trade_count   vwap
# 0         43.0  47.98
# 1         35.0  47.98
# 2         51.0  47.98
# 3         30.0  47.97
# 4         48.0  47.96

# %% [markdown]
# Great! if no errors were seen above, it means that everything is connected succesfully and all the functions below are ready to use. but first we start by testing our backfill function. The backfill function takes in input of start year, end year and symbols and it fetches the data from alpaca and stores it in parquets in our data/raw/\<symbol>/\<symbol>_\<year>.parquet. we test it in the next cell

# %%
run_backfill(symbols=["AAPL"], start_year=2024, end_year=2024)
# Out:
# Fetching AAPL 2024 from 2024-01-01 00:00:00 to 2025-01-01 00:00:00...
# Saved AAPL 2024 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/AAPL/AAPL_2024.parquet

# %% [markdown]
# If the cell ran and you daw saved, it means that the data was saved in the proper file, now we test load_parquet to make sure we see it in our folders before we pull the 200 symbols we want.

# %%
df_aapl = load_parquet("AAPL", 2024, DATA_DIR)
df_aapl.head()
# Out:
#   symbol                 timestamp    open    high     low   close   volume  \
# 0   AAPL 2024-01-02 09:00:00+00:00  191.52  191.52  190.00  190.20  18933.0
# 1   AAPL 2024-01-02 09:01:00+00:00  190.11  190.13  190.00  190.00   8562.0
# 2   AAPL 2024-01-02 09:02:00+00:00  189.90  189.90  189.82  189.82   5355.0
# 3   AAPL 2024-01-02 09:03:00+00:00  189.87  189.87  189.80  189.87   4405.0
# 4   AAPL 2024-01-02 09:04:00+00:00  189.90  189.95  189.90  189.90   2225.0
#
#    trade_count        vwap
# 0        612.0  190.241493
# 1        425.0  190.088775
# 2        129.0  189.823988
# 3         83.0  189.859107
# 4         87.0  189.916633

# %% [markdown]
# Great! now we can import all symbols, we have the symbols stored in configs/universe.yaml. we run the next cell to do so.
# # This will download all the files

# %%
run_full_backfill()
# Out:
# You are about to run a full-universe backfill.
# Number of tickers: 247
# Years: 2016 to 2026
# Total symbol-year jobs: 2717
# Overwrite existing files: False
# Type 'yes' to continue:  yes
# Backfilling symbols:   0%|          | 0/247 [00:00<?, ?symbol/s]
# Fetching NVDA 2016 from 2016-01-01 00:00:00 to 2017-01-01 00:00:00...
# Saved NVDA 2016 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/NVDA/NVDA_2016.parquet
# Fetching NVDA 2017 from 2017-01-01 00:00:00 to 2018-01-01 00:00:00...
# Saved NVDA 2017 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/NVDA/NVDA_2017.parquet
# Fetching NVDA 2018 from 2018-01-01 00:00:00 to 2019-01-01 00:00:00...
# Saved NVDA 2018 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/NVDA/NVDA_2018.parquet
# Fetching NVDA 2019 from 2019-01-01 00:00:00 to 2020-01-01 00:00:00...
# Saved NVDA 2019 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/NVDA/NVDA_2019.parquet
# Fetching NVDA 2020 from 2020-01-01 00:00:00 to 2021-01-01 00:00:00...
# Saved NVDA 2020 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/NVDA/NVDA_2020.parquet
# Fetching NVDA 2021 from 2021-01-01 00:00:00 to 2022-01-01 00:00:00...
# Saved NVDA 2021 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/NVDA/NVDA_2021.parquet
# Fetching NVDA 2022 from 2022-01-01 00:00:00 to 2023-01-01 00:00:00...
# Saved NVDA 2022 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/NVDA/NVDA_2022.parquet
# Fetching NVDA 2023 from 2023-01-01 00:00:00 to 2024-01-01 00:00:00...
# Saved NVDA 2023 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/NVDA/NVDA_2023.parquet
# Fetching NVDA 2024 from 2024-01-01 00:00:00 to 2025-01-01 00:00:00...
# Saved NVDA 2024 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/NVDA/NVDA_2024.parquet
# Fetching NVDA 2025 from 2025-01-01 00:00:00 to 2026-01-01 00:00:00...
# Saved NVDA 2025 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/NVDA/NVDA_2025.parquet
# Fetching NVDA 2026 from 2026-01-01 00:00:00 to 2026-03-08 00:00:00...
# Saved NVDA 2026 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/NVDA/NVDA_2026.parquet
# Fetching AAPL 2016 from 2016-01-01 00:00:00 to 2017-01-01 00:00:00...
# Saved AAPL 2016 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/AAPL/AAPL_2016.parquet
# Fetching AAPL 2017 from 2017-01-01 00:00:00 to 2018-01-01 00:00:00...
# Saved AAPL 2017 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/AAPL/AAPL_2017.parquet
# Fetching AAPL 2018 from 2018-01-01 00:00:00 to 2019-01-01 00:00:00...
# Saved AAPL 2018 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/AAPL/AAPL_2018.parquet
# Fetching AAPL 2019 from 2019-01-01 00:00:00 to 2020-01-01 00:00:00...
# Saved AAPL 2019 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/AAPL/AAPL_2019.parquet
# Fetching AAPL 2020 from 2020-01-01 00:00:00 to 2021-01-01 00:00:00...
# Saved AAPL 2020 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/AAPL/AAPL_2020.parquet
# Fetching AAPL 2021 from 2021-01-01 00:00:00 to 2022-01-01 00:00:00...
# Saved AAPL 2021 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/AAPL/AAPL_2021.parquet
# Fetching AAPL 2022 from 2022-01-01 00:00:00 to 2023-01-01 00:00:00...
# Saved AAPL 2022 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/AAPL/AAPL_2022.parquet
# Fetching AAPL 2023 from 2023-01-01 00:00:00 to 2024-01-01 00:00:00...
# Saved AAPL 2023 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/AAPL/AAPL_2023.parquet
# Skipping AAPL 2024 (already exists)
# Fetching AAPL 2025 from 2025-01-01 00:00:00 to 2026-01-01 00:00:00...
# Saved AAPL 2025 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/AAPL/AAPL_2025.parquet
# Fetching AAPL 2026 from 2026-01-01 00:00:00 to 2026-03-08 00:00:00...
# Saved AAPL 2026 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/AAPL/AAPL_2026.parquet
# Fetching GOOG 2016 from 2016-01-01 00:00:00 to 2017-01-01 00:00:00...
# Saved GOOG 2016 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/GOOG/GOOG_2016.parquet
# Fetching GOOG 2017 from 2017-01-01 00:00:00 to 2018-01-01 00:00:00...
# Saved GOOG 2017 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/GOOG/GOOG_2017.parquet
# Fetching GOOG 2018 from 2018-01-01 00:00:00 to 2019-01-01 00:00:00...
# Saved GOOG 2018 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/GOOG/GOOG_2018.parquet
# Fetching GOOG 2019 from 2019-01-01 00:00:00 to 2020-01-01 00:00:00...
# Saved GOOG 2019 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/GOOG/GOOG_2019.parquet
# Fetching GOOG 2020 from 2020-01-01 00:00:00 to 2021-01-01 00:00:00...
# Saved GOOG 2020 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/GOOG/GOOG_2020.parquet
# Fetching GOOG 2021 from 2021-01-01 00:00:00 to 2022-01-01 00:00:00...
# Saved GOOG 2021 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/GOOG/GOOG_2021.parquet
# Fetching GOOG 2022 from 2022-01-01 00:00:00 to 2023-01-01 00:00:00...
# Saved GOOG 2022 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/GOOG/GOOG_2022.parquet
# Fetching GOOG 2023 from 2023-01-01 00:00:00 to 2024-01-01 00:00:00...
# Saved GOOG 2023 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/GOOG/GOOG_2023.parquet
# Fetching GOOG 2024 from 2024-01-01 00:00:00 to 2025-01-01 00:00:00...
# Saved GOOG 2024 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/GOOG/GOOG_2024.parquet
# Fetching GOOG 2025 from 2025-01-01 00:00:00 to 2026-01-01 00:00:00...
# Saved GOOG 2025 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/GOOG/GOOG_2025.parquet
# Fetching GOOG 2026 from 2026-01-01 00:00:00 to 2026-03-08 00:00:00...
# Saved GOOG 2026 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/GOOG/GOOG_2026.parquet
# Fetching MSFT 2016 from 2016-01-01 00:00:00 to 2017-01-01 00:00:00...
# Saved MSFT 2016 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/MSFT/MSFT_2016.parquet
# Fetching MSFT 2017 from 2017-01-01 00:00:00 to 2018-01-01 00:00:00...
# Saved MSFT 2017 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/MSFT/MSFT_2017.parquet
# Fetching MSFT 2018 from 2018-01-01 00:00:00 to 2019-01-01 00:00:00...
# Saved MSFT 2018 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/MSFT/MSFT_2018.parquet
# Fetching MSFT 2019 from 2019-01-01 00:00:00 to 2020-01-01 00:00:00...
# Saved MSFT 2019 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/MSFT/MSFT_2019.parquet
# Fetching MSFT 2020 from 2020-01-01 00:00:00 to 2021-01-01 00:00:00...
# Saved MSFT 2020 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/MSFT/MSFT_2020.parquet
# Fetching MSFT 2021 from 2021-01-01 00:00:00 to 2022-01-01 00:00:00...
# Saved MSFT 2021 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/MSFT/MSFT_2021.parquet
# Fetching MSFT 2022 from 2022-01-01 00:00:00 to 2023-01-01 00:00:00...
# Saved MSFT 2022 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/MSFT/MSFT_2022.parquet
# Fetching MSFT 2023 from 2023-01-01 00:00:00 to 2024-01-01 00:00:00...
# Saved MSFT 2023 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/MSFT/MSFT_2023.parquet
# Fetching MSFT 2024 from 2024-01-01 00:00:00 to 2025-01-01 00:00:00...
# Saved MSFT 2024 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/MSFT/MSFT_2024.parquet
# Fetching MSFT 2025 from 2025-01-01 00:00:00 to 2026-01-01 00:00:00...
# Saved MSFT 2025 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/MSFT/MSFT_2025.parquet
# Fetching MSFT 2026 from 2026-01-01 00:00:00 to 2026-03-08 00:00:00...
# Saved MSFT 2026 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/MSFT/MSFT_2026.parquet
# Fetching AMZN 2016 from 2016-01-01 00:00:00 to 2017-01-01 00:00:00...
# Saved AMZN 2016 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/AMZN/AMZN_2016.parquet
# Fetching AMZN 2017 from 2017-01-01 00:00:00 to 2018-01-01 00:00:00...
# Saved AMZN 2017 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/AMZN/AMZN_2017.parquet
# Fetching AMZN 2018 from 2018-01-01 00:00:00 to 2019-01-01 00:00:00...
# Saved AMZN 2018 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/AMZN/AMZN_2018.parquet
# Fetching AMZN 2019 from 2019-01-01 00:00:00 to 2020-01-01 00:00:00...
# Saved AMZN 2019 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/AMZN/AMZN_2019.parquet
# Fetching AMZN 2020 from 2020-01-01 00:00:00 to 2021-01-01 00:00:00...
# Saved AMZN 2020 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/AMZN/AMZN_2020.parquet
# Fetching AMZN 2021 from 2021-01-01 00:00:00 to 2022-01-01 00:00:00...
# Saved AMZN 2021 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/AMZN/AMZN_2021.parquet
# Fetching AMZN 2022 from 2022-01-01 00:00:00 to 2023-01-01 00:00:00...
# Saved AMZN 2022 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/AMZN/AMZN_2022.parquet
# Fetching AMZN 2023 from 2023-01-01 00:00:00 to 2024-01-01 00:00:00...
# Saved AMZN 2023 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/AMZN/AMZN_2023.parquet
# Fetching AMZN 2024 from 2024-01-01 00:00:00 to 2025-01-01 00:00:00...
# Saved AMZN 2024 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/AMZN/AMZN_2024.parquet
# Fetching AMZN 2025 from 2025-01-01 00:00:00 to 2026-01-01 00:00:00...
# Saved AMZN 2025 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/AMZN/AMZN_2025.parquet
# Fetching AMZN 2026 from 2026-01-01 00:00:00 to 2026-03-08 00:00:00...
# Saved AMZN 2026 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/AMZN/AMZN_2026.parquet
# Fetching TSM 2016 from 2016-01-01 00:00:00 to 2017-01-01 00:00:00...
# Saved TSM 2016 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/TSM/TSM_2016.parquet
# Fetching TSM 2017 from 2017-01-01 00:00:00 to 2018-01-01 00:00:00...
# Saved TSM 2017 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/TSM/TSM_2017.parquet
# Fetching TSM 2018 from 2018-01-01 00:00:00 to 2019-01-01 00:00:00...
# Saved TSM 2018 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/TSM/TSM_2018.parquet
# Fetching TSM 2019 from 2019-01-01 00:00:00 to 2020-01-01 00:00:00...
# Saved TSM 2019 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/TSM/TSM_2019.parquet
# Fetching TSM 2020 from 2020-01-01 00:00:00 to 2021-01-01 00:00:00...
# Saved TSM 2020 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/TSM/TSM_2020.parquet
# Fetching TSM 2021 from 2021-01-01 00:00:00 to 2022-01-01 00:00:00...
# Saved TSM 2021 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/TSM/TSM_2021.parquet
# Fetching TSM 2022 from 2022-01-01 00:00:00 to 2023-01-01 00:00:00...
# Saved TSM 2022 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/TSM/TSM_2022.parquet
# Fetching TSM 2023 from 2023-01-01 00:00:00 to 2024-01-01 00:00:00...
# Saved TSM 2023 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/TSM/TSM_2023.parquet
# Fetching TSM 2024 from 2024-01-01 00:00:00 to 2025-01-01 00:00:00...
# Saved TSM 2024 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/TSM/TSM_2024.parquet
# Fetching TSM 2025 from 2025-01-01 00:00:00 to 2026-01-01 00:00:00...
# Saved TSM 2025 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/TSM/TSM_2025.parquet
# Fetching TSM 2026 from 2026-01-01 00:00:00 to 2026-03-08 00:00:00...
# Saved TSM 2026 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/TSM/TSM_2026.parquet
# Fetching META 2016 from 2016-01-01 00:00:00 to 2017-01-01 00:00:00...
# Saved META 2016 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/META/META_2016.parquet
# Fetching META 2017 from 2017-01-01 00:00:00 to 2018-01-01 00:00:00...
# Saved META 2017 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/META/META_2017.parquet
# Fetching META 2018 from 2018-01-01 00:00:00 to 2019-01-01 00:00:00...
# Saved META 2018 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/META/META_2018.parquet
# Fetching META 2019 from 2019-01-01 00:00:00 to 2020-01-01 00:00:00...
# Saved META 2019 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/META/META_2019.parquet
# Fetching META 2020 from 2020-01-01 00:00:00 to 2021-01-01 00:00:00...
# Saved META 2020 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/META/META_2020.parquet
# Fetching META 2021 from 2021-01-01 00:00:00 to 2022-01-01 00:00:00...
# Saved META 2021 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/META/META_2021.parquet
# Fetching META 2022 from 2022-01-01 00:00:00 to 2023-01-01 00:00:00...
# Saved META 2022 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/META/META_2022.parquet
# Fetching META 2023 from 2023-01-01 00:00:00 to 2024-01-01 00:00:00...
# Saved META 2023 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/META/META_2023.parquet
# Fetching META 2024 from 2024-01-01 00:00:00 to 2025-01-01 00:00:00...
# Saved META 2024 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/META/META_2024.parquet
# Fetching META 2025 from 2025-01-01 00:00:00 to 2026-01-01 00:00:00...
# Saved META 2025 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/META/META_2025.parquet
# Fetching META 2026 from 2026-01-01 00:00:00 to 2026-03-08 00:00:00...
# Saved META 2026 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/META/META_2026.parquet
# Fetching AVGO 2016 from 2016-01-01 00:00:00 to 2017-01-01 00:00:00...
# Saved AVGO 2016 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/AVGO/AVGO_2016.parquet
# Fetching AVGO 2017 from 2017-01-01 00:00:00 to 2018-01-01 00:00:00...
# Saved AVGO 2017 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/AVGO/AVGO_2017.parquet
# Fetching AVGO 2018 from 2018-01-01 00:00:00 to 2019-01-01 00:00:00...
# Saved AVGO 2018 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/AVGO/AVGO_2018.parquet
# Fetching AVGO 2019 from 2019-01-01 00:00:00 to 2020-01-01 00:00:00...
# Saved AVGO 2019 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/AVGO/AVGO_2019.parquet
# Fetching AVGO 2020 from 2020-01-01 00:00:00 to 2021-01-01 00:00:00...
# Saved AVGO 2020 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/AVGO/AVGO_2020.parquet
# Fetching AVGO 2021 from 2021-01-01 00:00:00 to 2022-01-01 00:00:00...
# Saved AVGO 2021 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/AVGO/AVGO_2021.parquet
# Fetching AVGO 2022 from 2022-01-01 00:00:00 to 2023-01-01 00:00:00...
# Saved AVGO 2022 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/AVGO/AVGO_2022.parquet
# Fetching AVGO 2023 from 2023-01-01 00:00:00 to 2024-01-01 00:00:00...
# Saved AVGO 2023 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/AVGO/AVGO_2023.parquet
# Fetching AVGO 2024 from 2024-01-01 00:00:00 to 2025-01-01 00:00:00...
# Saved AVGO 2024 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/AVGO/AVGO_2024.parquet
# Fetching AVGO 2025 from 2025-01-01 00:00:00 to 2026-01-01 00:00:00...
# Saved AVGO 2025 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/AVGO/AVGO_2025.parquet
# Fetching AVGO 2026 from 2026-01-01 00:00:00 to 2026-03-08 00:00:00...
# Saved AVGO 2026 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/AVGO/AVGO_2026.parquet
# Fetching TSLA 2016 from 2016-01-01 00:00:00 to 2017-01-01 00:00:00...
# Saved TSLA 2016 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/TSLA/TSLA_2016.parquet
# Fetching TSLA 2017 from 2017-01-01 00:00:00 to 2018-01-01 00:00:00...
# Saved TSLA 2017 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/TSLA/TSLA_2017.parquet
# Fetching TSLA 2018 from 2018-01-01 00:00:00 to 2019-01-01 00:00:00...
# Saved TSLA 2018 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/TSLA/TSLA_2018.parquet
# Fetching TSLA 2019 from 2019-01-01 00:00:00 to 2020-01-01 00:00:00...
# Saved TSLA 2019 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/TSLA/TSLA_2019.parquet
# Fetching TSLA 2020 from 2020-01-01 00:00:00 to 2021-01-01 00:00:00...
# Saved TSLA 2020 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/TSLA/TSLA_2020.parquet
# Fetching TSLA 2021 from 2021-01-01 00:00:00 to 2022-01-01 00:00:00...
# Saved TSLA 2021 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/TSLA/TSLA_2021.parquet
# Fetching TSLA 2022 from 2022-01-01 00:00:00 to 2023-01-01 00:00:00...
# Saved TSLA 2022 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/TSLA/TSLA_2022.parquet
# Fetching TSLA 2023 from 2023-01-01 00:00:00 to 2024-01-01 00:00:00...
# Saved TSLA 2023 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/TSLA/TSLA_2023.parquet
# Fetching TSLA 2024 from 2024-01-01 00:00:00 to 2025-01-01 00:00:00...
# Saved TSLA 2024 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/TSLA/TSLA_2024.parquet
# Fetching TSLA 2025 from 2025-01-01 00:00:00 to 2026-01-01 00:00:00...
# Saved TSLA 2025 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/TSLA/TSLA_2025.parquet
# Fetching TSLA 2026 from 2026-01-01 00:00:00 to 2026-03-08 00:00:00...
# Saved TSLA 2026 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/TSLA/TSLA_2026.parquet
# Fetching 005930.KS 2016 from 2016-01-01 00:00:00 to 2017-01-01 00:00:00...
# Failed for 005930.KS 2016: {"message":"invalid symbol: 005930.KS"}
#
# Fetching 005930.KS 2017 from 2017-01-01 00:00:00 to 2018-01-01 00:00:00...
# Failed for 005930.KS 2017: {"message":"invalid symbol: 005930.KS"}
#
# Fetching 005930.KS 2018 from 2018-01-01 00:00:00 to 2019-01-01 00:00:00...
# Failed for 005930.KS 2018: {"message":"invalid symbol: 005930.KS"}
#
# Fetching 005930.KS 2019 from 2019-01-01 00:00:00 to 2020-01-01 00:00:00...
# Failed for 005930.KS 2019: {"message":"invalid symbol: 005930.KS"}
#
# Fetching 005930.KS 2020 from 2020-01-01 00:00:00 to 2021-01-01 00:00:00...
# Failed for 005930.KS 2020: {"message":"invalid symbol: 005930.KS"}
#
# Fetching 005930.KS 2021 from 2021-01-01 00:00:00 to 2022-01-01 00:00:00...
# Failed for 005930.KS 2021: {"message":"invalid symbol: 005930.KS"}
#
# Fetching 005930.KS 2022 from 2022-01-01 00:00:00 to 2023-01-01 00:00:00...
# Failed for 005930.KS 2022: {"message":"invalid symbol: 005930.KS"}
#
# Fetching 005930.KS 2023 from 2023-01-01 00:00:00 to 2024-01-01 00:00:00...
# Failed for 005930.KS 2023: {"message":"invalid symbol: 005930.KS"}
#
# Fetching 005930.KS 2024 from 2024-01-01 00:00:00 to 2025-01-01 00:00:00...
# Failed for 005930.KS 2024: {"message":"invalid symbol: 005930.KS"}
#
# Fetching 005930.KS 2025 from 2025-01-01 00:00:00 to 2026-01-01 00:00:00...
# Failed for 005930.KS 2025: {"message":"invalid symbol: 005930.KS"}
#
# Fetching 005930.KS 2026 from 2026-01-01 00:00:00 to 2026-03-08 00:00:00...
# Failed for 005930.KS 2026: {"message":"invalid symbol: 005930.KS"}
#
# Fetching TECHY 2016 from 2016-01-01 00:00:00 to 2017-01-01 00:00:00...
# No data returned for TECHY 2016
# Fetching TECHY 2017 from 2017-01-01 00:00:00 to 2018-01-01 00:00:00...
# No data returned for TECHY 2017
# Fetching TECHY 2018 from 2018-01-01 00:00:00 to 2019-01-01 00:00:00...
# No data returned for TECHY 2018
# Fetching TECHY 2019 from 2019-01-01 00:00:00 to 2020-01-01 00:00:00...
# No data returned for TECHY 2019
# Fetching TECHY 2020 from 2020-01-01 00:00:00 to 2021-01-01 00:00:00...
# No data returned for TECHY 2020
# Fetching TECHY 2021 from 2021-01-01 00:00:00 to 2022-01-01 00:00:00...
# No data returned for TECHY 2021
# Fetching TECHY 2022 from 2022-01-01 00:00:00 to 2023-01-01 00:00:00...
# No data returned for TECHY 2022
# Fetching TECHY 2023 from 2023-01-01 00:00:00 to 2024-01-01 00:00:00...
# No data returned for TECHY 2023
# Fetching TECHY 2024 from 2024-01-01 00:00:00 to 2025-01-01 00:00:00...
# No data returned for TECHY 2024
# Fetching TECHY 2025 from 2025-01-01 00:00:00 to 2026-01-01 00:00:00...
# No data returned for TECHY 2025
# Fetching TECHY 2026 from 2026-01-01 00:00:00 to 2026-03-08 00:00:00...
# No data returned for TECHY 2026
# Fetching ASML 2016 from 2016-01-01 00:00:00 to 2017-01-01 00:00:00...
# Saved ASML 2016 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/ASML/ASML_2016.parquet
# Fetching ASML 2017 from 2017-01-01 00:00:00 to 2018-01-01 00:00:00...
# Saved ASML 2017 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/ASML/ASML_2017.parquet
# Fetching ASML 2018 from 2018-01-01 00:00:00 to 2019-01-01 00:00:00...
# Saved ASML 2018 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/ASML/ASML_2018.parquet
# Fetching ASML 2019 from 2019-01-01 00:00:00 to 2020-01-01 00:00:00...
# Saved ASML 2019 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/ASML/ASML_2019.parquet
# Fetching ASML 2020 from 2020-01-01 00:00:00 to 2021-01-01 00:00:00...
# Saved ASML 2020 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/ASML/ASML_2020.parquet
# Fetching ASML 2021 from 2021-01-01 00:00:00 to 2022-01-01 00:00:00...
# Saved ASML 2021 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/ASML/ASML_2021.parquet
# Fetching ASML 2022 from 2022-01-01 00:00:00 to 2023-01-01 00:00:00...
# Saved ASML 2022 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/ASML/ASML_2022.parquet
# Fetching ASML 2023 from 2023-01-01 00:00:00 to 2024-01-01 00:00:00...
# Saved ASML 2023 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/ASML/ASML_2023.parquet
# Fetching ASML 2024 from 2024-01-01 00:00:00 to 2025-01-01 00:00:00...
# Saved ASML 2024 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/ASML/ASML_2024.parquet
# Fetching ASML 2025 from 2025-01-01 00:00:00 to 2026-01-01 00:00:00...
# Saved ASML 2025 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/ASML/ASML_2025.parquet
# Fetching ASML 2026 from 2026-01-01 00:00:00 to 2026-03-08 00:00:00...
# Saved ASML 2026 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/ASML/ASML_2026.parquet
# Fetching ORCL 2016 from 2016-01-01 00:00:00 to 2017-01-01 00:00:00...
# Saved ORCL 2016 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/ORCL/ORCL_2016.parquet
# Fetching ORCL 2017 from 2017-01-01 00:00:00 to 2018-01-01 00:00:00...
# Saved ORCL 2017 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/ORCL/ORCL_2017.parquet
# Fetching ORCL 2018 from 2018-01-01 00:00:00 to 2019-01-01 00:00:00...
# Saved ORCL 2018 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/ORCL/ORCL_2018.parquet
# Fetching ORCL 2019 from 2019-01-01 00:00:00 to 2020-01-01 00:00:00...
# Saved ORCL 2019 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/ORCL/ORCL_2019.parquet
# Fetching ORCL 2020 from 2020-01-01 00:00:00 to 2021-01-01 00:00:00...
# Saved ORCL 2020 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/ORCL/ORCL_2020.parquet
# Fetching ORCL 2021 from 2021-01-01 00:00:00 to 2022-01-01 00:00:00...
# Saved ORCL 2021 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/ORCL/ORCL_2021.parquet
# Fetching ORCL 2022 from 2022-01-01 00:00:00 to 2023-01-01 00:00:00...
# Saved ORCL 2022 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/ORCL/ORCL_2022.parquet
# Fetching ORCL 2023 from 2023-01-01 00:00:00 to 2024-01-01 00:00:00...
# Saved ORCL 2023 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/ORCL/ORCL_2023.parquet
# Fetching ORCL 2024 from 2024-01-01 00:00:00 to 2025-01-01 00:00:00...
# Saved ORCL 2024 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/ORCL/ORCL_2024.parquet
# Fetching ORCL 2025 from 2025-01-01 00:00:00 to 2026-01-01 00:00:00...
# Saved ORCL 2025 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/ORCL/ORCL_2025.parquet
# Fetching ORCL 2026 from 2026-01-01 00:00:00 to 2026-03-08 00:00:00...
# Saved ORCL 2026 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/ORCL/ORCL_2026.parquet
# Fetching 000660.KS 2016 from 2016-01-01 00:00:00 to 2017-01-01 00:00:00...
# Failed for 000660.KS 2016: {"message":"invalid symbol: 000660.KS"}
#
# Fetching 000660.KS 2017 from 2017-01-01 00:00:00 to 2018-01-01 00:00:00...
# Failed for 000660.KS 2017: {"message":"invalid symbol: 000660.KS"}
#
# Fetching 000660.KS 2018 from 2018-01-01 00:00:00 to 2019-01-01 00:00:00...
# Failed for 000660.KS 2018: {"message":"invalid symbol: 000660.KS"}
#
# Fetching 000660.KS 2019 from 2019-01-01 00:00:00 to 2020-01-01 00:00:00...
# Failed for 000660.KS 2019: {"message":"invalid symbol: 000660.KS"}
#
# Fetching 000660.KS 2020 from 2020-01-01 00:00:00 to 2021-01-01 00:00:00...
# Failed for 000660.KS 2020: {"message":"invalid symbol: 000660.KS"}
#
# Fetching 000660.KS 2021 from 2021-01-01 00:00:00 to 2022-01-01 00:00:00...
# Failed for 000660.KS 2021: {"message":"invalid symbol: 000660.KS"}
#
# Fetching 000660.KS 2022 from 2022-01-01 00:00:00 to 2023-01-01 00:00:00...
# Failed for 000660.KS 2022: {"message":"invalid symbol: 000660.KS"}
#
# Fetching 000660.KS 2023 from 2023-01-01 00:00:00 to 2024-01-01 00:00:00...
# Failed for 000660.KS 2023: {"message":"invalid symbol: 000660.KS"}
#
# Fetching 000660.KS 2024 from 2024-01-01 00:00:00 to 2025-01-01 00:00:00...
# Failed for 000660.KS 2024: {"message":"invalid symbol: 000660.KS"}
#
# Fetching 000660.KS 2025 from 2025-01-01 00:00:00 to 2026-01-01 00:00:00...
# Failed for 000660.KS 2025: {"message":"invalid symbol: 000660.KS"}
#
# Fetching 000660.KS 2026 from 2026-01-01 00:00:00 to 2026-03-08 00:00:00...
# Failed for 000660.KS 2026: {"message":"invalid symbol: 000660.KS"}
#
# Fetching NFLX 2016 from 2016-01-01 00:00:00 to 2017-01-01 00:00:00...
# Saved NFLX 2016 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/NFLX/NFLX_2016.parquet
# Fetching NFLX 2017 from 2017-01-01 00:00:00 to 2018-01-01 00:00:00...
# Saved NFLX 2017 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/NFLX/NFLX_2017.parquet
# Fetching NFLX 2018 from 2018-01-01 00:00:00 to 2019-01-01 00:00:00...
# Saved NFLX 2018 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/NFLX/NFLX_2018.parquet
# Fetching NFLX 2019 from 2019-01-01 00:00:00 to 2020-01-01 00:00:00...
# Saved NFLX 2019 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/NFLX/NFLX_2019.parquet
# Fetching NFLX 2020 from 2020-01-01 00:00:00 to 2021-01-01 00:00:00...
# Saved NFLX 2020 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/NFLX/NFLX_2020.parquet
# Fetching NFLX 2021 from 2021-01-01 00:00:00 to 2022-01-01 00:00:00...
# Saved NFLX 2021 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/NFLX/NFLX_2021.parquet
# Fetching NFLX 2022 from 2022-01-01 00:00:00 to 2023-01-01 00:00:00...
# Saved NFLX 2022 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/NFLX/NFLX_2022.parquet
# Fetching NFLX 2023 from 2023-01-01 00:00:00 to 2024-01-01 00:00:00...
# Saved NFLX 2023 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/NFLX/NFLX_2023.parquet
# Fetching NFLX 2024 from 2024-01-01 00:00:00 to 2025-01-01 00:00:00...
# Saved NFLX 2024 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/NFLX/NFLX_2024.parquet
# Fetching NFLX 2025 from 2025-01-01 00:00:00 to 2026-01-01 00:00:00...
# Saved NFLX 2025 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/NFLX/NFLX_2025.parquet
# Fetching NFLX 2026 from 2026-01-01 00:00:00 to 2026-03-08 00:00:00...
# Saved NFLX 2026 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/NFLX/NFLX_2026.parquet
# Fetching MU 2016 from 2016-01-01 00:00:00 to 2017-01-01 00:00:00...
# Saved MU 2016 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/MU/MU_2016.parquet
# Fetching MU 2017 from 2017-01-01 00:00:00 to 2018-01-01 00:00:00...
# Saved MU 2017 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/MU/MU_2017.parquet
# Fetching MU 2018 from 2018-01-01 00:00:00 to 2019-01-01 00:00:00...
# Saved MU 2018 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/MU/MU_2018.parquet
# Fetching MU 2019 from 2019-01-01 00:00:00 to 2020-01-01 00:00:00...
# Saved MU 2019 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/MU/MU_2019.parquet
# Fetching MU 2020 from 2020-01-01 00:00:00 to 2021-01-01 00:00:00...
# Saved MU 2020 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/MU/MU_2020.parquet
# Fetching MU 2021 from 2021-01-01 00:00:00 to 2022-01-01 00:00:00...
# Saved MU 2021 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/MU/MU_2021.parquet
# Fetching MU 2022 from 2022-01-01 00:00:00 to 2023-01-01 00:00:00...
# Saved MU 2022 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/MU/MU_2022.parquet
# Fetching MU 2023 from 2023-01-01 00:00:00 to 2024-01-01 00:00:00...
# Saved MU 2023 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/MU/MU_2023.parquet
# Fetching MU 2024 from 2024-01-01 00:00:00 to 2025-01-01 00:00:00...
# Saved MU 2024 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/MU/MU_2024.parquet
# Fetching MU 2025 from 2025-01-01 00:00:00 to 2026-01-01 00:00:00...
# Saved MU 2025 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/MU/MU_2025.parquet
# Fetching MU 2026 from 2026-01-01 00:00:00 to 2026-03-08 00:00:00...
# Saved MU 2026 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/MU/MU_2026.parquet
# Fetching PLTR 2016 from 2016-01-01 00:00:00 to 2017-01-01 00:00:00...
# No data returned for PLTR 2016
# Fetching PLTR 2017 from 2017-01-01 00:00:00 to 2018-01-01 00:00:00...
# No data returned for PLTR 2017
# Fetching PLTR 2018 from 2018-01-01 00:00:00 to 2019-01-01 00:00:00...
# No data returned for PLTR 2018
# Fetching PLTR 2019 from 2019-01-01 00:00:00 to 2020-01-01 00:00:00...
# No data returned for PLTR 2019
# Fetching PLTR 2020 from 2020-01-01 00:00:00 to 2021-01-01 00:00:00...
# Saved PLTR 2020 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/PLTR/PLTR_2020.parquet
# Fetching PLTR 2021 from 2021-01-01 00:00:00 to 2022-01-01 00:00:00...
# Saved PLTR 2021 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/PLTR/PLTR_2021.parquet
# Fetching PLTR 2022 from 2022-01-01 00:00:00 to 2023-01-01 00:00:00...
# Saved PLTR 2022 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/PLTR/PLTR_2022.parquet
# Fetching PLTR 2023 from 2023-01-01 00:00:00 to 2024-01-01 00:00:00...
# Saved PLTR 2023 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/PLTR/PLTR_2023.parquet
# Fetching PLTR 2024 from 2024-01-01 00:00:00 to 2025-01-01 00:00:00...
# Saved PLTR 2024 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/PLTR/PLTR_2024.parquet
# Fetching PLTR 2025 from 2025-01-01 00:00:00 to 2026-01-01 00:00:00...
# Saved PLTR 2025 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/PLTR/PLTR_2025.parquet
# Fetching PLTR 2026 from 2026-01-01 00:00:00 to 2026-03-08 00:00:00...
# Saved PLTR 2026 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/PLTR/PLTR_2026.parquet
# Fetching AMD 2016 from 2016-01-01 00:00:00 to 2017-01-01 00:00:00...
# Saved AMD 2016 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/AMD/AMD_2016.parquet
# Fetching AMD 2017 from 2017-01-01 00:00:00 to 2018-01-01 00:00:00...
# Saved AMD 2017 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/AMD/AMD_2017.parquet
# Fetching AMD 2018 from 2018-01-01 00:00:00 to 2019-01-01 00:00:00...
# Saved AMD 2018 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/AMD/AMD_2018.parquet
# Fetching AMD 2019 from 2019-01-01 00:00:00 to 2020-01-01 00:00:00...
# Saved AMD 2019 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/AMD/AMD_2019.parquet
# Fetching AMD 2020 from 2020-01-01 00:00:00 to 2021-01-01 00:00:00...
# Saved AMD 2020 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/AMD/AMD_2020.parquet
# Fetching AMD 2021 from 2021-01-01 00:00:00 to 2022-01-01 00:00:00...
# Saved AMD 2021 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/AMD/AMD_2021.parquet
# Fetching AMD 2022 from 2022-01-01 00:00:00 to 2023-01-01 00:00:00...
# Saved AMD 2022 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/AMD/AMD_2022.parquet
# Fetching AMD 2023 from 2023-01-01 00:00:00 to 2024-01-01 00:00:00...
# Saved AMD 2023 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/AMD/AMD_2023.parquet
# Fetching AMD 2024 from 2024-01-01 00:00:00 to 2025-01-01 00:00:00...
# Saved AMD 2024 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/AMD/AMD_2024.parquet
# Fetching AMD 2025 from 2025-01-01 00:00:00 to 2026-01-01 00:00:00...
# Saved AMD 2025 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/AMD/AMD_2025.parquet
# Fetching AMD 2026 from 2026-01-01 00:00:00 to 2026-03-08 00:00:00...
# Saved AMD 2026 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/AMD/AMD_2026.parquet
# Fetching BABA 2016 from 2016-01-01 00:00:00 to 2017-01-01 00:00:00...
# Saved BABA 2016 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/BABA/BABA_2016.parquet
# Fetching BABA 2017 from 2017-01-01 00:00:00 to 2018-01-01 00:00:00...
# Saved BABA 2017 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/BABA/BABA_2017.parquet
# Fetching BABA 2018 from 2018-01-01 00:00:00 to 2019-01-01 00:00:00...
# Saved BABA 2018 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/BABA/BABA_2018.parquet
# Fetching BABA 2019 from 2019-01-01 00:00:00 to 2020-01-01 00:00:00...
# Saved BABA 2019 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/BABA/BABA_2019.parquet
# Fetching BABA 2020 from 2020-01-01 00:00:00 to 2021-01-01 00:00:00...
# Saved BABA 2020 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/BABA/BABA_2020.parquet
# Fetching BABA 2021 from 2021-01-01 00:00:00 to 2022-01-01 00:00:00...
# Saved BABA 2021 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/BABA/BABA_2021.parquet
# Fetching BABA 2022 from 2022-01-01 00:00:00 to 2023-01-01 00:00:00...
# Saved BABA 2022 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/BABA/BABA_2022.parquet
# Fetching BABA 2023 from 2023-01-01 00:00:00 to 2024-01-01 00:00:00...
# Saved BABA 2023 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/BABA/BABA_2023.parquet
# Fetching BABA 2024 from 2024-01-01 00:00:00 to 2025-01-01 00:00:00...
# Saved BABA 2024 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/BABA/BABA_2024.parquet
# Fetching BABA 2025 from 2025-01-01 00:00:00 to 2026-01-01 00:00:00...
# Saved BABA 2025 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/BABA/BABA_2025.parquet
# Fetching BABA 2026 from 2026-01-01 00:00:00 to 2026-03-08 00:00:00...
# Saved BABA 2026 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/BABA/BABA_2026.parquet
# Fetching CSCO 2016 from 2016-01-01 00:00:00 to 2017-01-01 00:00:00...
# Saved CSCO 2016 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/CSCO/CSCO_2016.parquet
# Fetching CSCO 2017 from 2017-01-01 00:00:00 to 2018-01-01 00:00:00...
# Saved CSCO 2017 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/CSCO/CSCO_2017.parquet
# Fetching CSCO 2018 from 2018-01-01 00:00:00 to 2019-01-01 00:00:00...
# Saved CSCO 2018 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/CSCO/CSCO_2018.parquet
# Fetching CSCO 2019 from 2019-01-01 00:00:00 to 2020-01-01 00:00:00...
# Saved CSCO 2019 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/CSCO/CSCO_2019.parquet
# Fetching CSCO 2020 from 2020-01-01 00:00:00 to 2021-01-01 00:00:00...
# Saved CSCO 2020 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/CSCO/CSCO_2020.parquet
# Fetching CSCO 2021 from 2021-01-01 00:00:00 to 2022-01-01 00:00:00...
# Saved CSCO 2021 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/CSCO/CSCO_2021.parquet
# Fetching CSCO 2022 from 2022-01-01 00:00:00 to 2023-01-01 00:00:00...
# Saved CSCO 2022 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/CSCO/CSCO_2022.parquet
# Fetching CSCO 2023 from 2023-01-01 00:00:00 to 2024-01-01 00:00:00...
# Saved CSCO 2023 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/CSCO/CSCO_2023.parquet
# Fetching CSCO 2024 from 2024-01-01 00:00:00 to 2025-01-01 00:00:00...
# Saved CSCO 2024 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/CSCO/CSCO_2024.parquet
# Fetching CSCO 2025 from 2025-01-01 00:00:00 to 2026-01-01 00:00:00...
# Saved CSCO 2025 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/CSCO/CSCO_2025.parquet
# Fetching CSCO 2026 from 2026-01-01 00:00:00 to 2026-03-08 00:00:00...
# Saved CSCO 2026 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/CSCO/CSCO_2026.parquet
# Fetching AMAT 2016 from 2016-01-01 00:00:00 to 2017-01-01 00:00:00...
# Saved AMAT 2016 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/AMAT/AMAT_2016.parquet
# Fetching AMAT 2017 from 2017-01-01 00:00:00 to 2018-01-01 00:00:00...
# Saved AMAT 2017 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/AMAT/AMAT_2017.parquet
# Fetching AMAT 2018 from 2018-01-01 00:00:00 to 2019-01-01 00:00:00...
# Saved AMAT 2018 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/AMAT/AMAT_2018.parquet
# Fetching AMAT 2019 from 2019-01-01 00:00:00 to 2020-01-01 00:00:00...
# Saved AMAT 2019 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/AMAT/AMAT_2019.parquet
# Fetching AMAT 2020 from 2020-01-01 00:00:00 to 2021-01-01 00:00:00...
# Saved AMAT 2020 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/AMAT/AMAT_2020.parquet
# Fetching AMAT 2021 from 2021-01-01 00:00:00 to 2022-01-01 00:00:00...
# Saved AMAT 2021 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/AMAT/AMAT_2021.parquet
# Fetching AMAT 2022 from 2022-01-01 00:00:00 to 2023-01-01 00:00:00...
# Saved AMAT 2022 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/AMAT/AMAT_2022.parquet
# Fetching AMAT 2023 from 2023-01-01 00:00:00 to 2024-01-01 00:00:00...
# Saved AMAT 2023 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/AMAT/AMAT_2023.parquet
# Fetching AMAT 2024 from 2024-01-01 00:00:00 to 2025-01-01 00:00:00...
# Saved AMAT 2024 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/AMAT/AMAT_2024.parquet
# Fetching AMAT 2025 from 2025-01-01 00:00:00 to 2026-01-01 00:00:00...
# Saved AMAT 2025 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/AMAT/AMAT_2025.parquet
# Fetching AMAT 2026 from 2026-01-01 00:00:00 to 2026-03-08 00:00:00...
# Saved AMAT 2026 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/AMAT/AMAT_2026.parquet
# Fetching LRCX 2016 from 2016-01-01 00:00:00 to 2017-01-01 00:00:00...
# Saved LRCX 2016 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/LRCX/LRCX_2016.parquet
# Fetching LRCX 2017 from 2017-01-01 00:00:00 to 2018-01-01 00:00:00...
# Saved LRCX 2017 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/LRCX/LRCX_2017.parquet
# Fetching LRCX 2018 from 2018-01-01 00:00:00 to 2019-01-01 00:00:00...
# Saved LRCX 2018 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/LRCX/LRCX_2018.parquet
# Fetching LRCX 2019 from 2019-01-01 00:00:00 to 2020-01-01 00:00:00...
# ...
# No data returned for MHVIY 2026
# Fetching WM 2016 from 2016-01-01 00:00:00 to 2017-01-01 00:00:00...
# Saved WM 2016 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/WM/WM_2016.parquet
# Fetching WM 2017 from 2017-01-01 00:00:00 to 2018-01-01 00:00:00...
# Saved WM 2017 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/WM/WM_2017.parquet
# Fetching WM 2018 from 2018-01-01 00:00:00 to 2019-01-01 00:00:00...
# Saved WM 2018 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/WM/WM_2018.parquet
# Fetching WM 2019 from 2019-01-01 00:00:00 to 2020-01-01 00:00:00...
# Saved WM 2019 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/WM/WM_2019.parquet
# Fetching WM 2020 from 2020-01-01 00:00:00 to 2021-01-01 00:00:00...
# Saved WM 2020 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/WM/WM_2020.parquet
# Fetching WM 2021 from 2021-01-01 00:00:00 to 2022-01-01 00:00:00...
# Saved WM 2021 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/WM/WM_2021.parquet
# Fetching WM 2022 from 2022-01-01 00:00:00 to 2023-01-01 00:00:00...
# Saved WM 2022 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/WM/WM_2022.parquet
# Fetching WM 2023 from 2023-01-01 00:00:00 to 2024-01-01 00:00:00...
# Saved WM 2023 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/WM/WM_2023.parquet
# Fetching WM 2024 from 2024-01-01 00:00:00 to 2025-01-01 00:00:00...
# Saved WM 2024 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/WM/WM_2024.parquet
# Fetching WM 2025 from 2025-01-01 00:00:00 to 2026-01-01 00:00:00...
# Saved WM 2025 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/WM/WM_2025.parquet
# Fetching WM 2026 from 2026-01-01 00:00:00 to 2026-03-09 00:00:00...
# Saved WM 2026 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/WM/WM_2026.parquet
# Fetching GD 2016 from 2016-01-01 00:00:00 to 2017-01-01 00:00:00...
# Saved GD 2016 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/GD/GD_2016.parquet
# Fetching GD 2017 from 2017-01-01 00:00:00 to 2018-01-01 00:00:00...
# Saved GD 2017 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/GD/GD_2017.parquet
# Fetching GD 2018 from 2018-01-01 00:00:00 to 2019-01-01 00:00:00...
# Saved GD 2018 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/GD/GD_2018.parquet
# Fetching GD 2019 from 2019-01-01 00:00:00 to 2020-01-01 00:00:00...
# Saved GD 2019 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/GD/GD_2019.parquet
# Fetching GD 2020 from 2020-01-01 00:00:00 to 2021-01-01 00:00:00...
# Saved GD 2020 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/GD/GD_2020.parquet
# Fetching GD 2021 from 2021-01-01 00:00:00 to 2022-01-01 00:00:00...
# Saved GD 2021 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/GD/GD_2021.parquet
# Fetching GD 2022 from 2022-01-01 00:00:00 to 2023-01-01 00:00:00...
# Saved GD 2022 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/GD/GD_2022.parquet
# Fetching GD 2023 from 2023-01-01 00:00:00 to 2024-01-01 00:00:00...
# Saved GD 2023 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/GD/GD_2023.parquet
# Fetching GD 2024 from 2024-01-01 00:00:00 to 2025-01-01 00:00:00...
# Saved GD 2024 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/GD/GD_2024.parquet
# Fetching GD 2025 from 2025-01-01 00:00:00 to 2026-01-01 00:00:00...
# Saved GD 2025 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/GD/GD_2025.parquet
# Fetching GD 2026 from 2026-01-01 00:00:00 to 2026-03-09 00:00:00...
# Saved GD 2026 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/GD/GD_2026.parquet
# Fetching ATLPF 2016 from 2016-01-01 00:00:00 to 2017-01-01 00:00:00...
# No data returned for ATLPF 2016
# Fetching ATLPF 2017 from 2017-01-01 00:00:00 to 2018-01-01 00:00:00...
# No data returned for ATLPF 2017
# Fetching ATLPF 2018 from 2018-01-01 00:00:00 to 2019-01-01 00:00:00...
# No data returned for ATLPF 2018
# Fetching ATLPF 2019 from 2019-01-01 00:00:00 to 2020-01-01 00:00:00...
# No data returned for ATLPF 2019
# Fetching ATLPF 2020 from 2020-01-01 00:00:00 to 2021-01-01 00:00:00...
# No data returned for ATLPF 2020
# Fetching ATLPF 2021 from 2021-01-01 00:00:00 to 2022-01-01 00:00:00...
# No data returned for ATLPF 2021
# Fetching ATLPF 2022 from 2022-01-01 00:00:00 to 2023-01-01 00:00:00...
# No data returned for ATLPF 2022
# Fetching ATLPF 2023 from 2023-01-01 00:00:00 to 2024-01-01 00:00:00...
# No data returned for ATLPF 2023
# Fetching ATLPF 2024 from 2024-01-01 00:00:00 to 2025-01-01 00:00:00...
# No data returned for ATLPF 2024
# Fetching ATLPF 2025 from 2025-01-01 00:00:00 to 2026-01-01 00:00:00...
# No data returned for ATLPF 2025
# Fetching ATLPF 2026 from 2026-01-01 00:00:00 to 2026-03-09 00:00:00...
# No data returned for ATLPF 2026
# Fetching ITOCF 2016 from 2016-01-01 00:00:00 to 2017-01-01 00:00:00...
# No data returned for ITOCF 2016
# Fetching ITOCF 2017 from 2017-01-01 00:00:00 to 2018-01-01 00:00:00...
# No data returned for ITOCF 2017
# Fetching ITOCF 2018 from 2018-01-01 00:00:00 to 2019-01-01 00:00:00...
# No data returned for ITOCF 2018
# Fetching ITOCF 2019 from 2019-01-01 00:00:00 to 2020-01-01 00:00:00...
# No data returned for ITOCF 2019
# Fetching ITOCF 2020 from 2020-01-01 00:00:00 to 2021-01-01 00:00:00...
# No data returned for ITOCF 2020
# Fetching ITOCF 2021 from 2021-01-01 00:00:00 to 2022-01-01 00:00:00...
# No data returned for ITOCF 2021
# Fetching ITOCF 2022 from 2022-01-01 00:00:00 to 2023-01-01 00:00:00...
# No data returned for ITOCF 2022
# Fetching ITOCF 2023 from 2023-01-01 00:00:00 to 2024-01-01 00:00:00...
# No data returned for ITOCF 2023
# Fetching ITOCF 2024 from 2024-01-01 00:00:00 to 2025-01-01 00:00:00...
# No data returned for ITOCF 2024
# Fetching ITOCF 2025 from 2025-01-01 00:00:00 to 2026-01-01 00:00:00...
# No data returned for ITOCF 2025
# Fetching ITOCF 2026 from 2026-01-01 00:00:00 to 2026-03-09 00:00:00...
# No data returned for ITOCF 2026
# Fetching ATLFF 2016 from 2016-01-01 00:00:00 to 2017-01-01 00:00:00...
# No data returned for ATLFF 2016
# Fetching ATLFF 2017 from 2017-01-01 00:00:00 to 2018-01-01 00:00:00...
# No data returned for ATLFF 2017
# Fetching ATLFF 2018 from 2018-01-01 00:00:00 to 2019-01-01 00:00:00...
# No data returned for ATLFF 2018
# Fetching ATLFF 2019 from 2019-01-01 00:00:00 to 2020-01-01 00:00:00...
# No data returned for ATLFF 2019
# Fetching ATLFF 2020 from 2020-01-01 00:00:00 to 2021-01-01 00:00:00...
# No data returned for ATLFF 2020
# Fetching ATLFF 2021 from 2021-01-01 00:00:00 to 2022-01-01 00:00:00...
# No data returned for ATLFF 2021
# Fetching ATLFF 2022 from 2022-01-01 00:00:00 to 2023-01-01 00:00:00...
# No data returned for ATLFF 2022
# Fetching ATLFF 2023 from 2023-01-01 00:00:00 to 2024-01-01 00:00:00...
# No data returned for ATLFF 2023
# Fetching ATLFF 2024 from 2024-01-01 00:00:00 to 2025-01-01 00:00:00...
# No data returned for ATLFF 2024
# Fetching ATLFF 2025 from 2025-01-01 00:00:00 to 2026-01-01 00:00:00...
# No data returned for ATLFF 2025
# Fetching ATLFF 2026 from 2026-01-01 00:00:00 to 2026-03-09 00:00:00...
# No data returned for ATLFF 2026
# Fetching TT 2016 from 2016-01-01 00:00:00 to 2017-01-01 00:00:00...
# Saved TT 2016 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/TT/TT_2016.parquet
# Fetching TT 2017 from 2017-01-01 00:00:00 to 2018-01-01 00:00:00...
# Saved TT 2017 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/TT/TT_2017.parquet
# Fetching TT 2018 from 2018-01-01 00:00:00 to 2019-01-01 00:00:00...
# Saved TT 2018 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/TT/TT_2018.parquet
# Fetching TT 2019 from 2019-01-01 00:00:00 to 2020-01-01 00:00:00...
# Saved TT 2019 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/TT/TT_2019.parquet
# Fetching TT 2020 from 2020-01-01 00:00:00 to 2021-01-01 00:00:00...
# Saved TT 2020 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/TT/TT_2020.parquet
# Fetching TT 2021 from 2021-01-01 00:00:00 to 2022-01-01 00:00:00...
# Saved TT 2021 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/TT/TT_2021.parquet
# Fetching TT 2022 from 2022-01-01 00:00:00 to 2023-01-01 00:00:00...
# Saved TT 2022 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/TT/TT_2022.parquet
# Fetching TT 2023 from 2023-01-01 00:00:00 to 2024-01-01 00:00:00...
# Saved TT 2023 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/TT/TT_2023.parquet
# Fetching TT 2024 from 2024-01-01 00:00:00 to 2025-01-01 00:00:00...
# Saved TT 2024 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/TT/TT_2024.parquet
# Fetching TT 2025 from 2025-01-01 00:00:00 to 2026-01-01 00:00:00...
# Saved TT 2025 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/TT/TT_2025.parquet
# Fetching TT 2026 from 2026-01-01 00:00:00 to 2026-03-09 00:00:00...
# Saved TT 2026 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/TT/TT_2026.parquet
# Fetching ATLKY 2016 from 2016-01-01 00:00:00 to 2017-01-01 00:00:00...
# No data returned for ATLKY 2016
# Fetching ATLKY 2017 from 2017-01-01 00:00:00 to 2018-01-01 00:00:00...
# No data returned for ATLKY 2017
# Fetching ATLKY 2018 from 2018-01-01 00:00:00 to 2019-01-01 00:00:00...
# No data returned for ATLKY 2018
# Fetching ATLKY 2019 from 2019-01-01 00:00:00 to 2020-01-01 00:00:00...
# No data returned for ATLKY 2019
# Fetching ATLKY 2020 from 2020-01-01 00:00:00 to 2021-01-01 00:00:00...
# No data returned for ATLKY 2020
# Fetching ATLKY 2021 from 2021-01-01 00:00:00 to 2022-01-01 00:00:00...
# No data returned for ATLKY 2021
# Fetching ATLKY 2022 from 2022-01-01 00:00:00 to 2023-01-01 00:00:00...
# No data returned for ATLKY 2022
# Fetching ATLKY 2023 from 2023-01-01 00:00:00 to 2024-01-01 00:00:00...
# No data returned for ATLKY 2023
# Fetching ATLKY 2024 from 2024-01-01 00:00:00 to 2025-01-01 00:00:00...
# No data returned for ATLKY 2024
# Fetching ATLKY 2025 from 2025-01-01 00:00:00 to 2026-01-01 00:00:00...
# No data returned for ATLKY 2025
# Fetching ATLKY 2026 from 2026-01-01 00:00:00 to 2026-03-09 00:00:00...
# No data returned for ATLKY 2026
# Fetching VRT 2016 from 2016-01-01 00:00:00 to 2017-01-01 00:00:00...
# No data returned for VRT 2016
# Fetching VRT 2017 from 2017-01-01 00:00:00 to 2018-01-01 00:00:00...
# No data returned for VRT 2017
# Fetching VRT 2018 from 2018-01-01 00:00:00 to 2019-01-01 00:00:00...
# Saved VRT 2018 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/VRT/VRT_2018.parquet
# Fetching VRT 2019 from 2019-01-01 00:00:00 to 2020-01-01 00:00:00...
# Saved VRT 2019 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/VRT/VRT_2019.parquet
# Fetching VRT 2020 from 2020-01-01 00:00:00 to 2021-01-01 00:00:00...
# Saved VRT 2020 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/VRT/VRT_2020.parquet
# Fetching VRT 2021 from 2021-01-01 00:00:00 to 2022-01-01 00:00:00...
# Saved VRT 2021 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/VRT/VRT_2021.parquet
# Fetching VRT 2022 from 2022-01-01 00:00:00 to 2023-01-01 00:00:00...
# Saved VRT 2022 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/VRT/VRT_2022.parquet
# Fetching VRT 2023 from 2023-01-01 00:00:00 to 2024-01-01 00:00:00...
# Saved VRT 2023 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/VRT/VRT_2023.parquet
# Fetching VRT 2024 from 2024-01-01 00:00:00 to 2025-01-01 00:00:00...
# Saved VRT 2024 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/VRT/VRT_2024.parquet
# Fetching VRT 2025 from 2025-01-01 00:00:00 to 2026-01-01 00:00:00...
# Saved VRT 2025 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/VRT/VRT_2025.parquet
# Fetching VRT 2026 from 2026-01-01 00:00:00 to 2026-03-09 00:00:00...
# Saved VRT 2026 to /Users/maxkeller/Desktop/QuantFinance/Quantitative-Finance-Projects/projects/regime_adaptive_alpha/data/raw/VRT/VRT_2026.parquet
# Fetching BAESF 2016 from 2016-01-01 00:00:00 to 2017-01-01 00:00:00...
# No data returned for BAESF 2016
# Fetching BAESF 2017 from 2017-01-01 00:00:00 to 2018-01-01 00:00:00...
# No data returned for BAESF 2017
# Fetching BAESF 2018 from 2018-01-01 00:00:00 to 2019-01-01 00:00:00...
# No data returned for BAESF 2018
# Fetching BAESF 2019 from 2019-01-01 00:00:00 to 2020-01-01 00:00:00...
# No data returned for BAESF 2019
# Fetching BAESF 2020 from 2020-01-01 00:00:00 to 2021-01-01 00:00:00...
# No data returned for BAESF 2020
# Fetching BAESF 2021 from 2021-01-01 00:00:00 to 2022-01-01 00:00:00...
# No data returned for BAESF 2021
# Fetching BAESF 2022 from 2022-01-01 00:00:00 to 2023-01-01 00:00:00...
# No data returned for BAESF 2022
# Fetching BAESF 2023 from 2023-01-01 00:00:00 to 2024-01-01 00:00:00...
# No data returned for BAESF 2023
# Fetching BAESF 2024 from 2024-01-01 00:00:00 to 2025-01-01 00:00:00...
# No data returned for BAESF 2024
# Fetching BAESF 2025 from 2025-01-01 00:00:00 to 2026-01-01 00:00:00...
# No data returned for BAESF 2025
# Fetching BAESF 2026 from 2026-01-01 00:00:00 to 2026-03-09 00:00:00...
# No data returned for BAESF 2026
# Fetching ITOCY 2016 from 2016-01-01 00:00:00 to 2017-01-01 00:00:00...
# No data returned for ITOCY 2016
# Fetching ITOCY 2017 from 2017-01-01 00:00:00 to 2018-01-01 00:00:00...
# No data returned for ITOCY 2017
# Fetching ITOCY 2018 from 2018-01-01 00:00:00 to 2019-01-01 00:00:00...
# No data returned for ITOCY 2018
# Fetching ITOCY 2019 from 2019-01-01 00:00:00 to 2020-01-01 00:00:00...
# No data returned for ITOCY 2019
# Fetching ITOCY 2020 from 2020-01-01 00:00:00 to 2021-01-01 00:00:00...
# No data returned for ITOCY 2020
# Fetching ITOCY 2021 from 2021-01-01 00:00:00 to 2022-01-01 00:00:00...
# No data returned for ITOCY 2021
# Fetching ITOCY 2022 from 2022-01-01 00:00:00 to 2023-01-01 00:00:00...
# No data returned for ITOCY 2022
# Fetching ITOCY 2023 from 2023-01-01 00:00:00 to 2024-01-01 00:00:00...
# No data returned for ITOCY 2023
# Fetching ITOCY 2024 from 2024-01-01 00:00:00 to 2025-01-01 00:00:00...
# No data returned for ITOCY 2024
# Fetching ITOCY 2025 from 2025-01-01 00:00:00 to 2026-01-01 00:00:00...
# No data returned for ITOCY 2025
# Fetching ITOCY 2026 from 2026-01-01 00:00:00 to 2026-03-09 00:00:00...
# No data returned for ITOCY 2026
# Full backfill complete.
